# %% [markdown]
# # The breast cancer dataset
#
# In [the breast cancer dataset](https://www.kaggle.com/datasets/yasserh/breast-cancer-dataset) we find different features and a classification whether a patient is diagnosed for breastcancer or not. You are required to build a classifier. Start with a logistic regression classifier. Use the same steps as given in the titanic example. Look into the documentation what you can tweak for a better performance.

# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns

# %%
df = pd.read_pickle('data/breast_cancer.pkl')
df.head()
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0    842302.0        1.0        17.99         10.38          122.80
# 1    842517.0        1.0        20.57         17.77          132.90
# 2  84300903.0        1.0        19.69         21.25          130.00
# 3  84348301.0        1.0        11.42         20.38           77.58
# 4  84358402.0        1.0        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1001.0          0.11840           0.27760          0.3001
# 1     1326.0          0.08474           0.07864          0.0869
# 2     1203.0          0.10960           0.15990          0.1974
# 3      386.1          0.14250           0.28390          0.2414
# 4     1297.0          0.10030           0.13280          0.1980
#
#    concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0              0.14710  ...         25.38          17.33           184.60
# ...

# %%
# First get some information about the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    float64
#  1   diagnosis                569 non-null    float64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# There does not seem to be any missing data right away, each variable appears three times (mean, se and worst) The data will be further explored and cleaned.

# %%
# See how many people have been diagnosed with benevolent(0)/malignant(1) tumors.
df['diagnosis'].value_counts()
# The distribution does not seem to be extreme, there is about 1,5 benevolent for each malignant.
# Out:
# 0.0    357
# 1.0    212
# Name: diagnosis, dtype: int64

# %%
cols = ['diagnosis',
        'radius_mean', 
        'texture_mean', 
        'perimeter_mean', 
        'area_mean', 
        'smoothness_mean', 
        'compactness_mean', 
        'concavity_mean',
        'concave points_mean', 
        'symmetry_mean', 
        'fractal_dimension_mean']

sns.pairplot(data=df[cols], hue='diagnosis', palette='RdBu')  # palette='husl'

# %% [markdown]
# There clearly seems to a difference between the two groups (diagnosis), however when looking at the plots on the main diagonal (distribution of the data), there seems to be a lot of overlap between them.

# %%
# Additionally, we create a correlation matrix to check how strongly components might be related.
# create a correlation matrix
c = df[cols].corr().abs()
sns.heatmap(c)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Besides the self-correlations, the strongest correlations appear to be radius and perimeter, radius and area. Considering they are so highly correlated, it might be best to remove them so they do not interfere with creating the model.

# %%
cols = ['texture_mean', 
        'area_mean', 
        'smoothness_mean', 
        'compactness_mean', 
        'concavity_mean',
        'concave points_mean', 
        'symmetry_mean', 
        'fractal_dimension_mean']

y = np.array(df['diagnosis'])
X = np.array(df[cols])
X.shape
# Out:
# (569, 8)

# %%
# The data ranges are very large and first need to be normalized before using Scikit learn
from sklearn.preprocessing import StandardScaler

def normalize(X):
    scalar = StandardScaler()
    scalar = scalar.fit(X)
    X = scalar.transform(X)
    return X

X = normalize(X)

# %%
# Split the data in train data and test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
# Train model that fits a regression curve to the data
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
history = logreg.fit(X_train, y_train)

# %%
# Evaluate trained model
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_pred = logreg.predict(X_test)
confusion_matrix = confusion_matrix(y_test, y_pred)
print ('=== [confusion matrix] ==='.center(54))
print(confusion_matrix)
print ('')
print ('=== [classification report] ==='.center(54))
print(classification_report(y_test, y_pred))
# Out:
#               === [confusion matrix] ===
# [[105   6]
#  [  6  54]]
#
#            === [classification report] ===
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95       111
#          1.0       0.90      0.90      0.90        60
#
#     accuracy                           0.93       171
#    macro avg       0.92      0.92      0.92       171
# weighted avg       0.93      0.93      0.93       171

# %% [markdown]
# According to the confusion matrix, there seems to be 102 true positives for 4 false negatives. With 5 false positives with 60 true negatives. This translates to about 95% precision and recall for the model. This suggests the model fits the data very well.

# %%
# Show the coefficients of the model
print(logreg.coef_)
# Out:
# [[ 1.3800126   2.49136762  0.66307331 -0.37619682  1.18326749  1.91137872
#    0.46915608 -0.54584505]]
